# %%
# input = Text file
# output = # of occurrences of every word

# %%
# Improvements:  (1) account for apostrophes or dashes in words, 
#                (2) account for abbreviations (respons. for responsibility)
#                (3)

def word_frequency(txt_file):
    handle_capitals = input("""
    Would you like to count capitalized words as a 
    separate word, or would you like me to make them all 
    lowercase? Please enter 'y' or 'n'!\n""")
    print_list = input("""
    Ok, now would you like to print your list of words and
    their count to the console?  Please enter 'y' or 'n'.\n""")
    
    # word_frequency("example.txt", c)
    with open(txt_file) as f:
        content = f.readlines()
    # result will hold final dictionary of words with count associated
    result = {}
    
    # ADDITIONS
    # handling capitals
    if handle_capitals.lower() == 'y' or handle_capitals.lower() == 'yes':
        print("Got it! Capitals will be made lower-case. Here is your list.\n")
        content = [x.lower() for x in content]
    if handle_capitals.lower() == 'n' or handle_capitals.lower() == 'no':
        print("Okay, capitals will be considered separately.  See below.\n")
    
    # stripping of leading/tailing spaces and '\n' markers
    content = [x.strip() for x in content]
    
    # splitting each line into its words
    content = [x.split(' ') for x in content]
    
    # for loop to process each word and remove punctuation around it
    for line in content:
        for word in line:            
            for c in string.punctuation:
                word = word.replace(c,"")
            
            # ADDITION BELOW
            # gets rid of quotations/spaces
            if word == "'" or word == "":
                continue
            if word in result:
                result[word] += 1
            elif word not in result:
                result[word] = 1

    if print_list.lower() == 'n' or print_list.lower() == 'no':
        None
    else:
        print("Total unique words in this file: \nAlphabetical Order (Word, Count)", len(result))
        for key in sorted(result):
            print("%s, %i" % (key, result[key]))
            
    return result

word_frequency('alice30.txt')
# Out:
#     Would you like to count capitalized words as a
#     separate word, or would you like me to make them all
#     lowercase? Please enter 'y' or 'n'!
# y
#
#     Ok, now would you like to print your list of words and
#     their count to the console?  Please enter 'y' or 'n'.
# y
# Got it! Capitals will be made lower-case. Here is your list.
#
# Total unique words in this file:
# Alphabetical Order (Word, Count) 2755
# , 1
# 30, 1
# a, 627
# abide, 1
# able, 1
# about, 94
# above, 3
# absence, 1
# absurd, 2
# acceptance, 1
# accident, 2
# accidentally, 1
# account, 1
# accounting, 1
# accounts, 1
# accusation, 1
# accustomed, 1
# ache, 1
# across, 5
# act, 1
# actually, 1
# ada, 1
# added, 23
# adding, 1
# addressed, 2
# addressing, 1
# adjourn, 1
# adoption, 1
# advance, 3
# advantage, 3
# adventures, 6
# adventuresbeginning, 1
# advice, 2
# advisable, 2
# advise, 1
# affair, 1
# affectionately, 1
# afford, 1
# afore, 1
# afraid, 12
# after, 42
# aftertime, 1
# afterwards, 2
# again, 82
# againbefore, 1
# against, 9
# age, 4
# ago, 2
# agony, 1
# agree, 2
# ah, 5
# ahem, 1
# aim, 1
# air, 14
# airs, 1
# alarm, 2
# alarmed, 1
# alas, 4
# alice, 386
# alices, 12
# alive, 3
# all, 180
# allow, 3
# almost, 6
# alone, 4
# along, 5
# alongcatch, 1
# aloud, 5
# already, 2
# also, 2
# altered, 1
# alternately, 1
# altogether, 5
# always, 12
# am, 15
# ambition, 1
# among, 12
# an, 57
# ancient, 1
# and, 845
# andbutter, 1
# andoh, 2
# anger, 2
# angrily, 9
# angry, 5
# animal, 1
# animals, 5
# ann, 4
# annoy, 1
# annoyed, 1
# another, 22
# answer, 9
# answered, 4
# answers, 1
# antipathies, 1
# anxious, 3
# anxiously, 14
# any, 39
# anything, 19
# anywhere, 1
# apiece, 1
# appealed, 1
# appear, 2
# appearance, 1
# appeared, 8
# appearing, 1
# applause, 1
# apples, 2
# arch, 1
# archbishop, 2
# arches, 4
# are, 53
# argue, 1
# argued, 1
# argument, 4
# arguments, 1
# arithmetic, 1
# arm, 12
# armchair, 1
# arminarm, 1
# arms, 6
# around, 3
# arranged, 1
# arrived, 1
# arrow, 1
# arrum, 1
# as, 262
# ashamed, 2
# ask, 11
# askance, 1
# asked, 17
# asking, 5
# asleep, 8
# assembled, 2
# at, 210
# ate, 1
# atheling, 1
# atom, 2
# attempt, 1
# attempted, 1
# attempts, 1
# attended, 1
# attending, 3
# attends, 1
# audibly, 1
# australia, 1
# authority, 2
# avoid, 1
# away, 25
# awfully, 1
# axes, 1
# axis, 1
# baby, 13
# back, 38
# backs, 1
# backsomersault, 1
# bad, 2
# bag, 1
# baked, 1
# balanced, 1
# balls, 1
# bank, 2
# banks, 1
# bankthe, 1
# banquet, 1
# bark, 2
# barking, 1
# barleysugar, 1
# barrowful, 2
# bat, 3
# bathing, 1
# bats, 4
# bawled, 1
# be, 146
# beak, 1
# bear, 1
# bearmind, 1
# beast, 1
# beasts, 2
# beat, 4
# beating, 2
# beauootiful, 4
# beautiful, 14
# beautifully, 2
# beautify, 1
# became, 2
# because, 15
# become, 5
# becoming, 1
# bed, 1
# beds, 1
# bee, 1
# been, 38
# before, 37
# beg, 8
# began, 58
# begged, 1
# begin, 13
# beginning, 13
# begins, 4
# begun, 7
# behead, 1
# beheaded, 3
# beheading, 1
# behind, 13
# being, 19
# believe, 9
# believed, 1
# bells, 1
# belong, 1
# belongs, 2
# beloved, 1
# below, 3
# belt, 1
# bend, 2
# bent, 1
# beor, 1
# besides, 4
# best, 12
# better, 14
# between, 6
# bill, 12
# bills, 3
# bird, 2
# birds, 9
# birthday, 1
# bit, 16
# bite, 2
# bitterandand, 1
# blacking, 1
# blades, 1
# blame, 1
# blasts, 2
# bleeds, 1
# blew, 2
# blow, 2
# blown, 1
# blows, 1
# body, 2
# boldly, 1
# bone, 1
# bones, 1
# book, 7
# books, 1
# bookshelves, 1
# boon, 1
# boots, 4
# bore, 1
# both, 14
# bother, 1
# bottle, 10
# bottom, 4
# bough, 1
# bound, 1
# bowed, 4
# bowing, 1
# box, 4
# boxed, 1
# boy, 2
# boyand, 1
# brain, 1
# branch, 1
# branches, 2
# brass, 1
# brave, 1
# bread, 1
# breadandbutter, 5
# breadknife, 1
# break, 2
# breath, 4
# breathe, 3
# breeze, 1
# bright, 7
# brightened, 2
# brighteyed, 1
# bring, 3
# bringing, 3
# bristling, 1
# broke, 2
# broken, 6
# brothers, 1
# brought, 3
# brown, 2
# brush, 1
# brushing, 1
# burn, 2
# burning, 1
# burnt, 1
# burst, 1
# bursting, 1
# busily, 4
# business, 7
# busy, 2
# but, 166
# butter, 3
# buttercup, 1
# buttered, 1
# butterfly, 1
# buttons, 1
# by, 56
# bythe, 1
# bythebye, 1
# cackled, 1
# cake, 3
# cakes, 3
# call, 9
# called, 15
# calling, 1
# calmly, 1
# came, 40
# camomile, 1
# can, 35
# canary, 1
# candle, 3
# cannot, 1
# cant, 28
# canterbury, 1
# canvas, 1
# capering, 1
# capital, 4
# cardboard, 1
# cards, 3
# care, 4
# carefully, 3
# cares, 2
# carried, 4
# carrier, 1
# carroll, 1
# carry, 1
# carrying, 2
# carthorse, 1
# cartwheels, 1
# case, 5
# cat, 35
# catch, 3
# catching, 2
# caterpillar, 27
# caterpillars, 1
# cats, 15
# cattle, 1
# caucusrace, 3
# caught, 3
# cauldron, 2
# cause, 3
# caused, 2
# cautiously, 3
# ceiling, 1
# centre, 1
# certain, 3
# certainly, 14
# chains, 1
# chance, 4
# chanced, 1
# change, 14
# changed, 8
# changes, 2
# changing, 2
# chapter, 12
# character, 1
# charges, 1
# chatte, 1
# cheap, 1
# cheated, 1
# checked, 3
# cheeks, 1
# cheered, 3
# cheerfully, 1
# cherrytart, 1
# cheshire, 7
# chief, 1
# child, 10
# childhood, 1
# childlife, 1
# children, 10
# chimney, 5
# chimneynay, 1
# chimneys, 1
# chin, 7
# choice, 2
# choke, 1
# choked, 3
# choking, 1
# choosing, 1
# chop, 1
# chorus, 6
# chose, 2
# christmas, 1
# chrysalisyou, 1
# chuckled, 1
# circle, 1
# circumstances, 1
# civil, 3
# clamour, 1
# clapping, 1
# clasped, 1
# classics, 1
# claws, 2
# clean, 1
# clear, 2
# cleared, 1
# clearer, 1
# clearly, 1
# clever, 2
# climb, 1
# clinging, 1
# clock, 2
# close, 13
# closed, 2
# closely, 1
# closer, 1
# clubs, 1
# coast, 1
# coaxing, 2
# coils, 1
# cold, 1
# collar, 1
# collected, 2
# come, 46
# comes, 2
# comfits, 2
# comfort, 1
# comfortable, 1
# comfortably, 1
# coming, 9
# common, 1
# commotion, 1
# company, 1
# complained, 1
# complaining, 1
# completely, 1
# concert, 2
# concluded, 2
# conclusion, 2
# condemn, 1
# conduct, 1
# confused, 4
# confusing, 3
# confusion, 5
# congereel, 1
# conqueror, 2
# conquest, 1
# consented, 1
# consider, 4
# considered, 3
# considering, 3
# constant, 2
# consultation, 1
# contempt, 1
# contemptuous, 1
# contemptuously, 2
# content, 1
# continued, 9
# contradicted, 1
# conversation, 10
# conversations, 1
# cook, 13
# cool, 2
# corner, 3
# cornerno, 1
# corners, 1
# cost, 1
# could, 77
# couldnt, 9
# counting, 1
# country, 1
# couple, 1
# couples, 1
# courage, 3
# course, 25
# court, 18
# courtiers, 2
# coward, 1
# crab, 3
# crash, 2
# crashed, 1
# crashnow, 1
# crawled, 1
# crawling, 1
# crazy, 1
# creature, 4
# creatures, 10
# creep, 1
# crept, 1
# cried, 20
# cries, 1
# crimson, 2
# crocodile, 1
# croquet, 6
# croqueted, 1
# croquetground, 3
# croqueting, 1
# cross, 1
# crossed, 3
# crossexamine, 2
# crossly, 1
# crouched, 1
# crowd, 4
# crowded, 5
# crown, 3
# crumbs, 4
# cry, 3
# crying, 2
# cucumberframe, 1
# cucumberframes, 1
# cunning, 1
# cup, 2
# cupboards, 2
# cur, 1
# curiosity, 5
# curious, 19
# curiouser, 2
# curled, 2
# curls, 1
# curly, 1
# currants, 1
# curtain, 1
# curtsey, 1
# curtseying, 1
# curving, 1
# cushion, 2
# custard, 1
# custody, 2
# cut, 5
# cutting, 1
# d, 1
# dainties, 1
# daisies, 1
# daisychain, 1
# dance, 13
# dancing, 2
# dare, 5
# daresay, 1
# dark, 3
# darkness, 1
# dates, 1
# daughter, 1
# day, 25
# days, 4
# dayschool, 1
# dead, 4
# deal, 12
# dear, 29
# dears, 3
# death, 1
# decided, 3
# decidedly, 4
# declare, 2
# declared, 1
# deep, 7
# deepest, 1
# deeply, 4
# delay, 1
# delight, 3
# delighted, 2
# delightful, 2
# denial, 1
# denied, 2
# denies, 1
# deny, 2
# denying, 1
# depends, 1
# derision, 1
# deserved, 1
# despair, 1
# desperate, 1
# desperately, 1
# diamonds, 1
# did, 62
# didnt, 14
# die, 1
# died, 1
# different, 9
# difficult, 2
# difficulties, 1
# difficulty, 4
# dig, 1
# digging, 4
# diligently, 1
# dinah, 11
# dinahll, 2
# dinahs, 1
# dinn, 2
# dinner, 2
# dipped, 2
# directed, 2
# direction, 5
# directions, 3
# directly, 2
# disagree, 1
# disappeared, 2
# disappointment, 1
# disgust, 1
# dish, 4
# dishes, 2
# dismay, 1
# disobey, 1
# dispute, 2
# distance, 7
# distancebut, 1
# distant, 2
# distraction, 1
# dive, 1
# do, 81
# dodged, 1
# dodo, 13
# does, 9
# doesnt, 16
# dog, 2
# dogs, 4
# doing, 5
# done, 15
# dont, 60
# door, 29
# doori, 1
# doors, 2
# doorway, 1
# dormouse, 39
# dormouses, 1
# doth, 3
# double, 1
# doubledup, 1
# doubling, 1
# doubt, 4
# doubtful, 2
# doubtfully, 2
# down, 101
# downhere, 1
# downward, 1
# downwards, 1
# doze, 1
# dozing, 1
# draggled, 1
# draw, 7
# drawing, 1
# drawling, 1
# drawlingmaster, 1
# drawlingthe, 1
# dreadful, 2
# dreadfully, 6
# dream, 7
# dreamed, 1
# dreaming, 1
# dreamy, 1
# dressed, 1
# drew, 5
# dried, 1
# driest, 1
# drink, 7
# drinking, 1
# dripping, 1
# drive, 2
# drop, 1
# dropped, 5
# dropping, 1
# drowned, 1
# drunk, 2
# dry, 8
# duchess, 38
# duchesss, 3
# duck, 4
# dull, 3
# dunce, 1
# dutchess, 1
# each, 8
# eager, 3
# eagerly, 8
# eaglet, 3
# ear, 6
# earls, 2
# earnestly, 2
# ears, 5
# earth, 4
# easily, 3
# easy, 2
# eat, 18
# eaten, 1
# eating, 1
# eats, 1
# edgar, 1
# edge, 3
# edition, 1
# editions, 2
# educationsin, 1
# edwin, 2
# eeevening, 3
# eel, 1
# eels, 1
# effect, 3
# egg, 1
# eggs, 5
# either, 10
# elbow, 3
# elbows, 1
# elegant, 1
# eleventh, 1
# else, 10
# elsebut, 1
# elses, 1
# elsie, 1
# em, 3
# emphasis, 1
# empty, 1
# encourage, 1
# encouraged, 1
# encouraging, 2
# end, 18
# ending, 1
# energetic, 1
# engaged, 1
# england, 1
# english, 6
# engraved, 1
# enjoy, 1
# ennyworth, 1
# enormous, 1
# enough, 17
# enoughi, 1
# entangled, 2
# entirely, 2
# entrance, 1
# escape, 4
# esq, 1
# est, 1
# even, 19
# evening, 2
# ever, 21
# every, 12
# everybody, 8
# everything, 10
# everythings, 2
# evidence, 7
# evidently, 1
# exact, 1
# exactly, 8
# examining, 1
# excellent, 2
# except, 4
# exclaimed, 6
# exclamation, 1
# execute, 1
# executed, 6
# executes, 1
# execution, 2
# executioner, 5
# executioners, 1
# executiononce, 1
# executions, 2
# existence, 1
# expected, 1
# expecting, 3
# experiment, 2
# explain, 10
# explained, 1
# explanation, 2
# explanations, 1
# expressing, 1
# expression, 1
# extraordinary, 2
# extras, 1
# extremely, 2
# eye, 7
# eyelids, 1
# eyes, 27
# eyesand, 1
# eyestell, 1
# face, 14
# faceand, 1
# faces, 5
# fact, 8
# fading, 1
# failure, 1
# faint, 1
# fainting, 1
# faintly, 1
# fair, 1
# fairly, 1
# fairytales, 1
# fall, 7
# fallen, 4
# falling, 2
# familiarly, 1
# family, 1
# fan, 10
# fancied, 2
# fancy, 5
# fancying, 1
# fancywhos, 1
# fanned, 1
# fanning, 1
# far, 13
# farmer, 1
# farmyardwhile, 1
# farther, 1
# fashion, 2
# fast, 4
# faster, 3
# fat, 1
# father, 6
# favoured, 1
# favourite, 1
# fear, 4
# feared, 1
# feather, 1
# feathers, 1
# feeble, 2
# feebly, 1
# feel, 8
# feeling, 7
# feelings, 2
# feet, 19
# fell, 6
# fellow, 4
# fellows, 1
# felt, 23
# fender, 1
# ferrets, 2
# fetch, 7
# few, 9
# fidgeted, 1
# field, 1
# fifteen, 1
# fifteenth, 1
# fifth, 1
# fig, 1
# fight, 2
# fighting, 1
# figure, 3
# figures, 1
# filled, 3
# fills, 1
# find, 21
# finding, 3
# finds, 1
# fine, 2
# finger, 5
# finish, 5
# finished, 12
# finishing, 1
# fire, 3
# fireirons, 1
# fireplace, 1
# first, 49
# firstthey, 1
# firstverdict, 1
# fish, 3
# fishand, 1
# fishes, 1
# fishfootman, 2
# fit, 3
# fits, 1
# fitted, 1
# five, 8
# fix, 1
# fixed, 1
# flame, 1
# flamingo, 5
# flamingoes, 2
# flapper, 1
# flappers, 1
# flashed, 1
# flat, 2
# flavour, 1
# flew, 1
# flinging, 1
# flock, 1
# floor, 3
# flowerbeds, 1
# flowerpot, 1
# flowers, 2
# flown, 1
# flung, 1
# flurry, 1
# flustered, 1
# fluttered, 1
# fly, 3
# flying, 1
# folded, 3
# folding, 1
# follow, 2
# followed, 8
# follows, 3
# fond, 3
# fondofof, 1
# foolish, 1
# foot, 10
# footman, 10
# footmans, 1
# footmen, 1
# footsteps, 2
# for, 153
# forehead, 2
# forepaws, 1
# forget, 2
# forgetting, 3
# forgot, 2
# forgotten, 6
# fork, 1
# form, 1
# fortunately, 1
# fortytwo, 1
# forwards, 1
# found, 32
# fountains, 2
# four, 6
# fourteenth, 1
# fourth, 1
# france, 1
# free, 3
# french, 4
# friend, 3
# friends, 2
# fright, 2
# frighten, 1
# frightened, 7
# frog, 2
# frogfootman, 1
# from, 36
# front, 2
# frontispiece, 1
# frowning, 4
# fryingpan, 1
# fulcrum, 1
# full, 6
# fumbled, 1
# fun, 3
# funny, 3
# fur, 3
# furious, 1
# furiously, 1
# furrow, 1
# furrows, 1
# further, 3
# fury, 3
# gained, 1
# gallons, 1
# game, 12
# games, 2
# garden, 15
# gardeners, 8
# gardenhow, 1
# gather, 1
# gave, 15
# gay, 1
# gazing, 1
# general, 3
# generally, 7
# gently, 3
# geography, 1
# get, 46
# getting, 22
# giddy, 2
# girl, 4
# girls, 3
# give, 12
# given, 1
# giving, 2
# glad, 11
# glanced, 1
# glaring, 1
# glass, 10
# globe, 1
# gloomily, 1
# gloves, 10
# glovesthat, 1
# go, 50
# goes, 7
# going, 27
# golden, 7
# goldfish, 2
# gone, 13
# good, 25
# goodbye, 1
# goodnaturedly, 1
# goose, 2
# got, 45
# graceful, 1
# grammar, 1
# grand, 3
# grant, 1
# grass, 4
# grave, 3
# gravely, 3
# gravy, 1
# grazed, 1
# great, 39
# green, 4
# grew, 1
# grey, 1
# grief, 1
# grin, 6
# grinned, 3
# grinning, 1
# grins, 1
# ground, 4
# groundand, 1
# grow, 13
# growing, 11
# growl, 3
# growled, 1
# growling, 1
# growls, 1
# grown, 7
# grumbled, 1
# grunt, 1
# grunted, 4
# gryphon, 55
# guard, 1
# guess, 3
# guessed, 3
# guests, 3
# guilt, 1
# guineapig, 2
# guineapigs, 4
# had, 178
# hadnt, 8
# hair, 7
# half, 21
# halfpast, 2
# hall, 9
# hand, 20
# handed, 3
# hands, 12
# handsome, 1
# handwriting, 1
# hanging, 3
# happen, 8
# happened, 7
# happening, 1
# happens, 5
# happy, 1
# hard, 8
# hardly, 12
# hare, 31
# harm, 1
# has, 7
# hasnt, 2
# haste, 1
# hastily, 16
# hat, 1
# hatching, 1
# hate, 1
# hatec, 1
# hated, 1
# hatter, 55
# hatters, 2
# have, 80
# havent, 8
# having, 10
# he, 120
# head, 48
# headbrandy, 1
# heads, 11
# heap, 1
# hear, 14
# heard, 30
# hearing, 4
# heart, 2
# hearth, 1
# hearthrug, 1
# hearts, 8
# heavy, 2
# hed, 1
# hedge, 2
# hedgehog, 7
# hedgehogs, 3
# hedges, 1
# heels, 1
# height, 5
# held, 4
# hell, 1
# help, 9
# helped, 1
# helpless, 1
# her, 248
# herald, 1
# here, 49
# hers, 3
# herself, 83
# hersshe, 1
# hes, 3
# hid, 1
# hide, 1
# high, 16
# highest, 1
# him, 41
# himhow, 1
# himit, 1
# himself, 6
# hint, 2
# hippopotamus, 1
# his, 96
# hiss, 1
# histories, 1
# history, 7
# hit, 2
# hjckrrh, 1
# hm, 1
# hoarse, 3
# hoarsely, 1
# hold, 9
# holding, 3
# holiday, 1
# hollow, 1
# home, 5
# honest, 1
# honour, 4
# hookah, 5
# hope, 3
# hoped, 1
# hopeful, 1
# hopeless, 1
# hoping, 3
# hot, 5
# hottempered, 1
# hour, 2
# hours, 4
# house, 18
# housemaid, 1
# houses, 1
# how, 64
# however, 20
# howled, 1
# howling, 3
# humble, 1
# humbly, 2
# hundred, 1
# hung, 1
# hungry, 3
# hunting, 3
# hurried, 11
# hurriedly, 2
# hurry, 11
# hurrying, 1
# hurt, 3
# hush, 3
# i, 401
# id, 11
# idea, 15
# idiot, 1
# idiotic, 1
# if, 94
# ifif, 1
# ignorant, 1
# ii, 2
# iii, 1
# iim, 1
# ill, 33
# im, 57
# imagine, 2
# imitated, 1
# immediate, 1
# immediately, 3
# immense, 1
# impatient, 1
# impatiently, 5
# impertinent, 1
# important, 5
# importantunimportant, 1
# impossible, 3
# improve, 1
# in, 366
# incessantly, 1
# inches, 6
# inclined, 1
# indeed, 16
# indignant, 1
# indignantly, 4
# injure, 1
# ink, 1
# inkstand, 1
# inquired, 1
# inquisitively, 1
# inside, 2
# insolence, 1
# instance, 3
# instantly, 5
# instead, 3
# insult, 1
# interest, 1
# interesting, 5
# interrupt, 1
# interrupted, 9
# interrupting, 2
# into, 67
# introduce, 2
# introduced, 1
# invent, 1
# invented, 1
# invitation, 2
# invited, 2
# involved, 1
# inwards, 1
# irritated, 1
# is, 102
# isbe, 1
# isbirds, 1
# isnt, 7
# isoh, 2
# istake, 1
# isthe, 1
# it, 526
# itll, 8
# itonce, 1
# its, 111
# itself, 14
# itsits, 1
# itthat, 1
# iv, 1
# ive, 34
# ix, 1
# jackinthebox, 1
# jar, 2
# jaw, 1
# jaws, 2
# jellyfish, 1
# jogged, 1
# join, 9
# joined, 3
# journey, 1
# joys, 1
# judge, 4
# judging, 1
# jumped, 6
# jumping, 4
# juror, 1
# jurors, 4
# jury, 17
# jurybox, 4
# jurymen, 5
# just, 51
# justice, 1
# keep, 11
# keeping, 2
# kept, 13
# kettle, 1
# key, 9
# kick, 3
# kid, 5
# kill, 1
# killing, 1
# kills, 1
# kind, 7
# kindly, 2
# king, 61
# kings, 3
# kiss, 1
# kissed, 1
# kitchen, 4
# knave, 9
# knee, 5
# kneel, 1
# knelt, 1
# knew, 14
# knife, 2
# knock, 1
# knocked, 1
# knocking, 3
# knot, 2
# know, 86
# knowand, 1
# knowing, 2
# knowledge, 3
# known, 1
# knowno, 1
# knows, 2
# knuckles, 1
# label, 2
# labelled, 1
# lacie, 1
# ladderwhy, 1
# ladhere, 1
# lady, 3
# laid, 2
# lamps, 1
# land, 1
# languid, 1
# lap, 2
# large, 33
# larger, 7
# largest, 1
# lark, 1
# last, 33
# lasted, 2
# lastly, 1
# late, 6
# lately, 1
# later, 3
# latin, 1
# latitude, 2
# laugh, 1
# laughed, 2
# laughing, 2
# laughter, 1
# law, 2
# lay, 4
# lazily, 1
# lazy, 1
# leaders, 1
# leading, 1
# leaning, 2
# leant, 1
# leap, 1
# learn, 7
# learned, 1
# learning, 2
# learnt, 2
# least, 8
# leastat, 1
# leave, 9
# leaves, 6
# leaving, 1
# led, 4
# ledge, 1
# left, 14
# lefthand, 2
# legs, 3
# length, 1
# less, 4
# lessen, 1
# lesson, 1
# lessonbook, 1
# lessonbooks, 1
# lessons, 10
# lest, 1
# let, 17
# lets, 5
# letter, 3
# letters, 1
# lewis, 1
# licking, 1
# lie, 2
# life, 11
# lifted, 1
# like, 85
# liked, 6
# likely, 5
# likes, 1
# limbs, 1
# line, 2
# lines, 1
# linked, 1
# lips, 1
# list, 3
# listen, 7
# listened, 1
# listeners, 1
# listening, 3
# lit, 1
# little, 128
# live, 8
# lived, 3
# livery, 3
# lives, 4
# living, 2
# lizard, 5
# lizards, 1
# lobster, 7
# lobsters, 7
# lock, 1
# locked, 1
# locks, 2
# lodging, 1
# london, 1
# lonely, 2
# long, 32
# longed, 2
# longer, 3
# longitude, 2
# look, 28
# looked, 45
# looking, 31
# lookout, 1
# loose, 1
# lory, 7
# lose, 1
# losing, 1
# lost, 3
# loud, 6
# louder, 1
# loudly, 3
# love, 3
# loveliest, 1
# lovely, 2
# loving, 1
# low, 14
# lower, 1
# lowing, 1
# lowspirited, 1
# luckily, 2
# lullaby, 1
# lying, 8
# m, 4
# ma, 2
# maam, 1
# mabel, 4
# machines, 1
# mad, 14
# madat, 1
# made, 30
# magic, 1
# magpie, 1
# majesty, 12
# make, 26
# makes, 11
# making, 8
# mallets, 1
# man, 5
# manage, 7
# managed, 4
# managing, 1
# manner, 2
# manners, 1
# many, 12
# maps, 1
# march, 33
# marched, 1
# marchjust, 1
# mark, 3
# marked, 6
# marmalade, 1
# mary, 4
# master, 3
# matter, 9
# matters, 2
# may, 13
# maybe, 1
# maynt, 1
# me, 68
# meal, 1
# mean, 10
# meaning, 8
# means, 4
# meanstomakeanythingprettier, 1
# meant, 5
# meanwhile, 1
# measure, 1
# meat, 1
# meekly, 2
# meet, 2
# meeting, 1
# melancholy, 6
# memorandum, 1
# memory, 1
# mentioned, 3
# mercia, 2
# merely, 2
# merrily, 1
# messages, 2
# met, 3
# mice, 3
# miceoh, 1
# middle, 7
# might, 28
# mile, 2
# miles, 3
# milk, 1
# milkjug, 1
# millennium, 1
# mind, 10
# minded, 1
# minding, 1
# mine, 8
# minea, 1
# mineral, 1
# minute, 21
# minutes, 11
# mischief, 1
# miserable, 2
# miss, 4
# missed, 2
# mistake, 3
# mixed, 2
# mock, 56
# moderate, 1
# modern, 1
# moment, 29
# moments, 2
# month, 2
# moon, 1
# moral, 8
# morals, 1
# morcar, 2
# more, 48
# moreas, 1
# morning, 5
# morsel, 1
# most, 8
# mostly, 2
# mournful, 1
# mournfully, 1
# mouse, 38
# mousea, 1
# mouseo, 1
# mouseof, 1
# mouses, 1
# mouseto, 1
# mousetraps, 1
# mouth, 10
# mouths, 3
# mouthsand, 1
# move, 3
# moved, 5
# moving, 3
# much, 51
# muchness, 2
# muchnessdid, 1
# muddle, 1
# multiplication, 1
# murder, 1
# murdering, 1
# muscular, 1
# mushroom, 8
# music, 3
# must, 44
# mustard, 2
# mustardmine, 1
# muttered, 2
# muttering, 3
# my, 58
# myself, 7
# mystery, 2
# name, 10
# names, 2
# narrow, 2
# nasty, 1
# natural, 4
# natured, 1
# near, 15
# nearer, 5
# nearly, 11
# neat, 1
# neatly, 2
# neck, 7
# neednt, 3
# needs, 1
# neighbour, 1
# neighbouring, 1
# neither, 2
# nervous, 5
# nest, 1
# never, 45
# neverending, 1
# nevertheless, 1
# new, 5
# newspapers, 1
# next, 30
# nibbled, 2
# nibbling, 3
# nice, 6
# nicely, 2
# night, 3
# nightair, 1
# nile, 1
# nine, 5
# no, 87
# nobody, 8
# nodded, 1
# noise, 3
# noises, 1
# none, 4
# nonsense, 7
# nor, 3
# normans, 1
# northumbria, 2
# nose, 8
# not, 144
# notebook, 2
# nothing, 34
# notice, 5
# noticed, 8
# noticing, 1
# notion, 3
# now, 57
# nowbut, 1
# nowdont, 1
# nowhere, 2
# number, 5
# nurse, 2
# nurseand, 1
# nursing, 3
# o, 2
# obliged, 3
# oblong, 1
# obstacle, 1
# occasional, 1
# occasionally, 1
# occurred, 2
# oclock, 3
# odd, 1
# of, 508
# off, 73
# offend, 1
# offended, 10
# offer, 2
# officer, 1
# officers, 4
# often, 5
# oh, 38
# ointmentone, 1
# old, 19
# older, 2
# oldest, 1
# on, 193
# once, 32
# one, 101
# onebut, 1
# ones, 2
# oneself, 1
# onions, 1
# only, 49
# open, 7
# opened, 10
# opening, 3
# opinion, 1
# opportunity, 8
# opposite, 1
# or, 76
# orange, 1
# order, 3
# ordered, 4
# ordering, 2
# ornamented, 2
# other, 39
# otherbill, 1
# others, 7
# otherwise, 4
# ou, 1
# ought, 14
# our, 8
# ours, 1
# ourselves, 1
# out, 113
# outoftheway, 3
# outside, 4
# over, 40
# overcome, 1
# overhead, 1
# owl, 3
# own, 10
# oyster, 1
# p, 1
# pace, 1
# pack, 5
# paint, 1
# painting, 2
# pair, 5
# pairs, 1
# pale, 4
# panted, 1
# panther, 3
# panting, 2
# paper, 4
# parchment, 2
# pardon, 6
# pardoned, 1
# paris, 2
# part, 2
# particular, 4
# partner, 1
# partners, 1
# parts, 1
# party, 8
# pass, 1
# passage, 4
# passed, 5
# passing, 1
# passion, 3
# passionate, 1
# past, 1
# pat, 2
# patience, 1
# patiently, 2
# patriotic, 1
# patted, 1
# pattering, 3
# pattern, 1
# pause, 2
# paused, 1
# paw, 3
# paws, 4
# pebbles, 2
# peeped, 3
# peeping, 1
# peering, 1
# pegs, 1
# pence, 1
# pencil, 1
# pencils, 1
# pennyworth, 1
# people, 13
# pepper, 7
# pepperbox, 1
# perfectly, 4
# perhaps, 17
# permitted, 1
# persisted, 2
# person, 4
# personal, 2
# persons, 1
# pet, 1
# picked, 3
# picking, 2
# picture, 1
# pictured, 1
# pictures, 4
# pie, 2
# piece, 5
# pieces, 3
# piecrust, 1
# pig, 8
# pigbaby, 1
# pigeon, 12
# pigs, 2
# pinch, 2
# pinched, 2
# pineapple, 1
# pink, 1
# piteous, 1
# pitied, 1
# pity, 3
# place, 8
# placed, 1
# places, 2
# plainly, 1
# plan, 4
# planning, 1
# plate, 3
# plates, 2
# play, 8
# played, 1
# players, 4
# playing, 2
# pleaded, 3
# pleasant, 1
# pleasanter, 1
# please, 19
# pleased, 7
# pleases, 1
# pleasing, 1
# pleasure, 2
# plenty, 2
# pocket, 6
# pointed, 1
# pointing, 4
# poison, 3
# poker, 1
# poky, 1
# politely, 6
# pool, 10
# poolshe, 1
# poor, 27
# pop, 1
# pope, 1
# porpoise, 4
# position, 2
# positively, 1
# possible, 1
# possibly, 3
# pounds, 1
# pour, 1
# poured, 1
# powdered, 1
# practice, 1
# pray, 3
# precious, 1
# present, 3
# presented, 1
# presently, 2
# presents, 2
# pressed, 3
# pressing, 1
# pretend, 1
# pretending, 1
# pretexts, 1
# pretty, 1
# prevent, 1
# printed, 1
# prison, 1
# prisoner, 1
# prisoners, 1
# prize, 1
# prizes, 5
# proceed, 2
# procession, 5
# processions, 1
# produced, 1
# producing, 1
# promise, 1
# promised, 1
# promising, 1
# pronounced, 1
# proper, 3
# proposal, 1
# prosecute, 1
# protection, 1
# proud, 2
# prove, 1
# proved, 2
# proves, 2
# provoking, 1
# puffed, 1
# pulled, 1
# pulling, 1
# pun, 1
# punching, 1
# punished, 1
# puppy, 6
# puppys, 1
# purple, 1
# purpose, 1
# purring, 2
# push, 1
# puss, 1
# put, 31
# putting, 3
# puzzle, 1
# puzzled, 9
# puzzling, 4
# quadrille, 4
# quarrel, 1
# quarrelled, 1
# quarrelling, 2
# queen, 68
# queens, 8
# queer, 11
# queerest, 1
# queerlooking, 1
# question, 17
# questions, 3
# questionshow, 1
# quick, 2
# quicker, 1
# quickly, 2
# quiet, 2
# quietly, 5
# quite, 55
# quiver, 1
# rabbit, 43
# rabbithole, 3
# rabbitholeand, 1
# rabbits, 4
# rabbitspat, 1
# race, 2
# racecourse, 1
# railway, 2
# raised, 2
# raising, 1
# ran, 16
# rapidly, 2
# rapped, 1
# rate, 9
# rather, 25
# rathole, 1
# rats, 1
# rattle, 1
# rattling, 2
# raven, 1
# ravens, 1
# raving, 2
# raw, 1
# reach, 4
# reaching, 1
# read, 11
# readily, 1
# reading, 3
# ready, 8
# real, 3
# realitythe, 1
# really, 13
# rearing, 1
# reason, 9
# reasonable, 1
# reasons, 1
# received, 1
# recognised, 1
# recovered, 2
# red, 2
# redhot, 1
# reduced, 1
# reedsthe, 1
# reeling, 1
# refreshments, 1
# refused, 1
# regular, 2
# relief, 2
# relieved, 1
# remain, 1
# remained, 3
# remaining, 1
# remark, 10
# remarkable, 2
# remarked, 10
# remarking, 3
# remarks, 3
# remedies, 1
# remember, 14
# remembered, 5
# remembering, 1
# reminding, 1
# removed, 2
# repeat, 7
# repeated, 10
# repeating, 3
# replied, 29
# reply, 5
# resource, 1
# respect, 1
# respectable, 1
# respectful, 1
# rest, 10
# resting, 2
# result, 1
# retire, 1
# returned, 2
# returning, 1
# rich, 1
# riddle, 1
# riddles, 1
# riddlesi, 1
# ridge, 1
# ridges, 1
# ridiculous, 1
# right, 31
# righthand, 2
# rightly, 1
# ring, 2
# ringlets, 2
# riper, 1
# rippling, 1
# rise, 1
# rises, 1
# rising, 1
# roared, 1
# roast, 1
# rock, 1
# rome, 1
# romeno, 1
# roof, 6
# room, 13
# roots, 1
# ropewill, 1
# rose, 1
# roses, 3
# rosetree, 4
# roughly, 1
# round, 41
# row, 2
# royal, 2
# rubbed, 1
# rubbing, 2
# rude, 2
# rudeness, 1
# rule, 5
# rules, 3
# rumbling, 1
# run, 4
# running, 8
# rush, 2
# rushed, 1
# rustled, 1
# rustling, 1
# sad, 3
# sadly, 5
# safe, 2
# sage, 1
# said, 462
# salmon, 1
# salt, 2
# same, 24
# sand, 1
# sands, 1
# sang, 2
# sat, 17
# saucepan, 1
# saucepans, 1
# saucer, 1
# savage, 4
# save, 1
# saves, 1
# saw, 14
# say, 50
# saying, 15
# says, 4
# saythats, 1
# scale, 1
# scaly, 1
# school, 5
# schoolroom, 1
# scolded, 1
# scrambling, 1
# scratching, 1
# scream, 2
# screamed, 4
# screaming, 1
# scroll, 2
# sea, 13
# seals, 1
# seaography, 1
# search, 1
# seashore, 1
# seaside, 1
# seated, 1
# second, 4
# secondly, 2
# secret, 1
# see, 66
# seehow, 1
# seeing, 1
# seem, 8
# seemed, 27
# seems, 5
# seen, 14
# seeneverything, 1
# seldom, 1
# sell, 2
# send, 1
# sending, 2
# sends, 1
# sensation, 2
# sense, 3
# sent, 2
# sentence, 6
# sentenced, 1
# series, 1
# seriously, 1
# serpent, 9
# serpents, 3
# set, 14
# setting, 1
# settle, 1
# settled, 3
# settling, 1
# seven, 6
# several, 4
# severely, 4
# severity, 1
# sh, 2
# shade, 1
# shake, 1
# shakespeare, 1
# shaking, 3
# shall, 25
# shant, 6
# shape, 1
# shaped, 3
# share, 1
# shared, 1
# sharing, 1
# shark, 1
# sharks, 1
# sharp, 6
# sharply, 4
# she, 537
# shed, 2
# shedding, 1
# sheep, 1
# shell, 3
# shelves, 1
# shepherd, 1
# shes, 7
# shifting, 1
# shilling, 1
# shillings, 1
# shinglewill, 1
# shining, 1
# shiny, 1
# shiver, 1
# shock, 1
# shoes, 7
# shook, 9
# shore, 3
# short, 4
# shorter, 2
# should, 27
# shoulder, 4
# shoulders, 4
# shouldnt, 5
# shouted, 9
# shouting, 2
# show, 3
# shower, 2
# showing, 2
# shriek, 5
# shrieked, 1
# shrieks, 1
# shrill, 5
# shrimp, 1
# shrink, 1
# shrinking, 4
# shut, 5
# shutting, 2
# shy, 1
# shyly, 1
# side, 17
# sides, 4
# sigh, 4
# sighed, 5
# sighing, 3
# sight, 10
# sign, 1
# signed, 2
# signifies, 1
# signify, 1
# silence, 14
# silent, 7
# simple, 5
# simpleton, 1
# simply, 2
# simplynever, 1
# since, 4
# sing, 6
# singers, 2
# singing, 2
# sink, 1
# sir, 7
# sister, 8
# sisters, 2
# sistersthey, 1
# sit, 8
# sits, 1
# sitting, 10
# six, 2
# sixpence, 1
# sixteenth, 1
# size, 13
# sizes, 1
# skimming, 1
# skirt, 1
# skurried, 1
# sky, 4
# skyrocket, 1
# slate, 2
# slateoh, 1
# slatepencil, 1
# slates, 7
# slatesll, 1
# sleep, 6
# sleepy, 5
# slightest, 1
# slipped, 3
# slippery, 1
# slowly, 8
# sluggard, 1
# small, 10
# smaller, 3
# smallest, 2
# smile, 2
# smiled, 2
# smiling, 2
# smoke, 1
# smoking, 2
# snail, 3
# snappishly, 1
# snatch, 2
# sneeze, 2
# sneezed, 1
# sneezes, 2
# sneezing, 6
# snorting, 1
# snout, 1
# so, 150
# soand, 1
# sob, 1
# sobbed, 1
# sobbing, 3
# sobs, 4
# soft, 1
# softly, 1
# soldier, 1
# soldiers, 10
# solemn, 3
# solemnly, 4
# soles, 1
# solid, 1
# some, 51
# somebody, 7
# somehow, 1
# someone, 1
# somersault, 1
# something, 18
# sometimes, 5
# somewhere, 3
# son, 1
# song, 7
# soon, 25
# sooner, 2
# soooop, 7
# soothing, 1
# sorrow, 2
# sorrowful, 2
# sorrows, 1
# sorry, 1
# sort, 20
# sorts, 3
# sound, 4
# sounded, 5
# sounds, 4
# soup, 18
# sourand, 1
# spades, 1
# speak, 14
# speakand, 1
# speaker, 1
# speaking, 5
# spectacles, 3
# speech, 3
# speed, 1
# spell, 1
# spite, 1
# splash, 1
# splashed, 1
# splashing, 2
# splendidly, 1
# spoke, 16
# spokefancy, 1
# spoken, 1
# spoon, 2
# spot, 1
# sprawling, 1
# spread, 3
# spreading, 1
# squeaked, 1
# squeaking, 2
# squeeze, 1
# squeezed, 1
# stairs, 3
# stalk, 1
# stamping, 2
# stand, 6
# standing, 1
# starfish, 1
# staring, 3
# started, 2
# startled, 2
# state, 1
# station, 1
# stay, 5
# stays, 1
# steady, 1
# steamengine, 1
# sternly, 1
# stick, 4
# sticks, 1
# stiff, 1
# stigand, 1
# still, 13
# stingy, 1
# stirring, 2
# stockings, 1
# stole, 2
# stolen, 1
# stood, 7
# stool, 1
# stoop, 2
# stop, 6
# stopped, 3
# stopping, 1
# story, 8
# straight, 2
# straightened, 1
# straightening, 1
# strange, 5
# strength, 1
# stretched, 2
# stretching, 2
# strings, 1
# struck, 2
# stuff, 4
# stupid, 6
# stupidest, 1
# stupidly, 1
# subdued, 1
# subject, 6
# subjects, 1
# submitted, 1
# succeeded, 3
# such, 41
# sudden, 5
# suddenly, 13
# suet, 1
# sugar, 1
# suit, 3
# sulkily, 2
# sulky, 3
# summer, 2
# sun, 2
# supple, 1
# suppose, 14
# suppress, 1
# suppressed, 4
# sure, 24
# surprise, 5
# surprised, 7
# swallow, 1
# swallowed, 1
# swallowing, 1
# swam, 5
# sweettempered, 1
# swim, 5
# swimming, 2
# t, 1
# table, 18
# tail, 9
# tails, 3
# take, 21
# taken, 4
# takes, 2
# taking, 5
# tale, 4
# talk, 14
# talking, 17
# taller, 2
# tarts, 7
# taste, 2
# tasted, 3
# tastes, 1
# taught, 4
# tea, 12
# teaching, 1
# teacup, 3
# teacups, 2
# teanot, 1
# teaparty, 2
# teapot, 1
# tears, 11
# teases, 1
# teathings, 1
# teatime, 2
# teatray, 1
# teeth, 1
# telescope, 3
# telescopes, 1
# tell, 31
# telling, 2
# tells, 2
# temper, 5
# ten, 6
# terms, 1
# terribly, 1
# terrier, 1
# terror, 1
# than, 24
# thank, 4
# thanked, 1
# that, 276
# thatched, 1
# thatit, 1
# thatll, 1
# thatonly, 1
# thats, 33
# the, 1630
# their, 52
# theirs, 1
# them, 84
# themall, 1
# themand, 2
# themi, 1
# themselves, 3
# then, 90
# thenalways, 1
# thenbills, 1
# theni, 1
# thenshe, 1
# there, 75
# therefore, 1
# theres, 24
# these, 14
# they, 128
# theyd, 4
# theyll, 4
# theyre, 13
# theyve, 1
# theyyouve, 1
# thick, 1
# thimble, 4
# thinand, 1
# thing, 49
# things, 28
# thingseverything, 1
# thingsi, 1
# think, 53
# thinking, 11
# thirteen, 1
# this, 134
# thistle, 2
# thoroughly, 2
# those, 10
# though, 12
# thought, 74
# thoughtfully, 4
# thoughts, 2
# thousand, 2
# three, 26
# threelegged, 2
# threw, 2
# throat, 2
# throne, 1
# through, 13
# throw, 3
# throwing, 2
# thrown, 1
# thump, 2
# thunder, 1
# thunderstorm, 1
# thy, 1
# tide, 1
# tidy, 1
# tie, 1
# tied, 1
# tight, 1
# till, 21
# tillie, 1
# time, 68
# times, 6
# timid, 3
# timidly, 9
# tinkling, 1
# tiny, 4
# tipped, 1
# tiptoe, 2
# tired, 7
# tis, 5
# tittered, 1
# to, 721
# toast, 1
# today, 4
# toes, 3
# toffee, 1
# together, 9
# told, 6
# tomorrow, 1
# tone, 40
# tones, 2
# tongue, 4
# tonight, 1
# too, 26
# took, 24
# top, 8
# tops, 1
# tortoise, 3
# toss, 1
# tossing, 3
# toto, 1
# touch, 1
# tougher, 1
# towards, 1
# toys, 1
# trampled, 1
# treacle, 5
# treaclewell, 1
# treaclewelleh, 1
# treading, 2
# treat, 1
# treated, 1
# tree, 5
# trees, 7
# tremble, 1
# trembled, 2
# trembling, 6
# tremulous, 1
# trial, 7
# trials, 4
# trickling, 1
# tricks, 1
# tried, 19
# trims, 1
# triumphantly, 2
# trot, 1
# trotting, 2
# trouble, 6
# true, 4
# trumpet, 3
# trusts, 1
# truth, 1
# truthful, 1
# try, 12
# trying, 14
# tucked, 3
# tuliproots, 1
# tumbled, 1
# tumbling, 2
# tunnel, 1
# tureen, 1
# turkey, 1
# turn, 10
# turned, 16
# turning, 12
# turns, 3
# turnup, 1
# turtle, 56
# turtles, 4
# turtlewe, 1
# tut, 2
# twelfth, 1
# twelve, 4
# twentieth, 1
# twenty, 1
# twentyfour, 2
# twice, 5
# twinkle, 8
# twinkled, 1
# twinkling, 4
# twist, 2
# two, 39
# ugh, 2
# uglification, 2
# uglify, 1
# uglifying, 1
# ugly, 2
# unable, 1
# uncivil, 1
# uncomfortable, 4
# uncomfortably, 1
# uncommon, 1
# uncommonly, 1
# uncorked, 1
# under, 16
# underneath, 1
# understand, 6
# understood, 1
# undertone, 2
# undo, 1
# undoing, 1
# uneasily, 2
# uneasy, 1
# unfolded, 2
# unfortunate, 3
# unhappy, 2
# unimportant, 3
# unimportantimportant, 1
# unjust, 1
# unless, 2
# unlocking, 1
# unpleasant, 2
# unrolled, 2
# until, 5
# untwist, 1
# unusually, 1
# unwillingly, 1
# up, 98
# upon, 26
# upright, 1
# upset, 3
# upsetting, 1
# upstairs, 1
# us, 14
# use, 18
# used, 12
# usedand, 1
# useful, 2
# using, 2
# usual, 5
# usually, 2
# usurpation, 1
# v, 1
# vague, 1
# vanished, 4
# vanishing, 1
# variations, 1
# various, 1
# vegetable, 1
# velvet, 1
# venture, 3
# ventured, 4
# verdict, 3
# verse, 4
# verses, 4
# very, 144
# vi, 1
# vii, 1
# viii, 1
# vinegar, 1
# violence, 1
# violent, 2
# violently, 4
# visit, 1
# voice, 47
# voices, 2
# voiceshold, 1
# voicethe, 1
# vote, 1
# vulgar, 1
# w, 1
# wag, 1
# wags, 1
# waist, 1
# waistcoat, 1
# waistcoatpocket, 1
# wait, 1
# waited, 11
# waiting, 9
# wake, 2
# walk, 5
# walked, 10
# walking, 5
# walrus, 1
# wander, 1
# wandered, 2
# wandering, 2
# want, 9
# wanted, 4
# wants, 2
# warning, 1
# was, 357
# wash, 2
# washing, 2
# washingextra, 1
# wasnt, 11
# waste, 1
# wasting, 2
# watch, 8
# watched, 2
# watching, 3
# water, 4
# waters, 1
# waterwell, 1
# waving, 5
# way, 52
# waynever, 1
# ways, 1
# we, 29
# weak, 2
# wearily, 1
# week, 3
# weeks, 1
# welcome, 1
# well, 60
# went, 83
# wept, 1
# were, 87
# werent, 1
# wet, 2
# weve, 2
# what, 136
# whatever, 3
# whats, 5
# when, 79
# whenever, 1
# where, 13
# wheres, 2
# whereupon, 1
# wherever, 2
# whether, 11
# which, 49
# while, 24
# whiles, 1
# whiskers, 3
# whisper, 3
# whispered, 5
# whispers, 1
# whistle, 1
# whistling, 1
# white, 30
# whiting, 8
# who, 61
# whoever, 1
# whole, 13
# whom, 1
# whos, 1
# whose, 2
# why, 39
# wide, 2
# wider, 1
# wife, 1
# wig, 2
# wild, 2
# wildly, 2
# will, 31
# william, 7
# williams, 1
# win, 1
# wind, 2
# window, 8
# wine, 2
# wings, 1
# wink, 2
# winter, 1
# wise, 2
# wish, 21
# with, 180
# within, 1
# withina, 1
# without, 25
# withoutmaybe, 1
# witness, 10
# wits, 1
# woke, 1
# woman, 2
# won, 2
# wonder, 18
# wondered, 1
# wonderful, 2
# wondering, 7
# wonderland, 3
# wont, 24
# wood, 7
# wooden, 1
# woodshe, 1
# word, 10
# words, 21
# wore, 1
# work, 8
# works, 1
# world, 7
# worm, 1
# worried, 1
# worry, 1
# worse, 3
# worth, 4
# would, 83
# wouldnt, 13
# wow, 6
# wrapping, 1
# wretched, 2
# wriggling, 1
# write, 6
# writhing, 1
# writing, 4
# writingdesk, 1
# writingdesks, 1
# written, 6
# wrong, 5
# wrote, 3
# x, 1
# xi, 1
# xii, 1
# yards, 1
# yawned, 2
# yawning, 2
# ye, 1
# year, 2
# years, 1
# yelled, 1
# yelp, 1
# yer, 4
# yes, 13
# yesterday, 3
# yet, 22
# yetand, 1
# yetits, 1
# yetoh, 1
# you, 362
# youall, 1
# youare, 1
# youd, 10
# youll, 6
# young, 5
# your, 62
# youre, 23
# yours, 3
# yourself, 10
# youth, 6
# youve, 6
# zealand, 1
# zigzag, 1
# {'repeating': 3,
#  'geography': 1,
#  'rushed': 1,
#  'writhing': 1,
#  'stupid': 6,
#  'faster': 3,
#  'curtseying': 1,
#  'bones': 1,
#  'sang': 2,
#  'bee': 1,
#  'as': 262,
#  'wink': 2,
#  'ah': 5,
#  'getting': 22,
#  'thoughts': 2,
#  'exclamation': 1,
#  'flamingoes': 2,
#  'salt': 2,
#  'remembering': 1,
#  'question': 17,
#  'stupidly': 1,
#  'wasnt': 11,
#  'lit': 1,
#  'singers': 2,
#  'forgotten': 6,
#  'mushroom': 8,
#  'elsebut': 1,
#  'piece': 5,
#  'annoyed': 1,
#  'nasty': 1,
#  'roared': 1,
#  'brain': 1,
#  'place': 8,
#  'great': 39,
#  'faces': 5,
#  'old': 19,
#  'lazily': 1,
#  'savage': 4,
#  'producing': 1,
#  'i': 401,
#  'grammar': 1,
#  'charges': 1,
#  'occasional': 1,
#  'somersault': 1,
#  'checked': 3,
#  'others': 7,
#  'consider': 4,
#  'clamour': 1,
#  'handwriting': 1,
#  'listening': 3,
#  'child': 10,
#  'guineapig': 2,
#  'cry': 3,
#  'general': 3,
#  'cheered': 3,
#  'such': 41,
#  'slates': 7,
#  'thoughtfully': 4,
#  'tired': 7,
#  'diligently': 1,
#  'true': 4,
#  'banquet': 1,
#  'riper': 1,
#  'telescope': 3,
#  'names': 2,
#  'large': 33,
#  'd': 1,
#  'caterpillar': 27,
#  'ceiling': 1,
#  'been': 38,
#  'fourth': 1,
#  'passing': 1,
#  'happy': 1,
#  'poky': 1,
#  'mouse': 38,
#  'scale': 1,
#  'sharks': 1,
#  'living': 2,
#  'golden': 7,
#  'himhow': 1,
#  'deepest': 1,
#  'dispute': 2,
#  'spot': 1,
#  'shrieks': 1,
#  'croqueting': 1,
#  'undoing': 1,
#  'waynever': 1,
#  'bite': 2,
#  'righthand': 2,
#  'hers': 3,
#  'sends': 1,
#  'mallets': 1,
#  'twentyfour': 2,
#  'pleasant': 1,
#  'soft': 1,
#  'duchesss': 3,
#  'yetand': 1,
#  'rise': 1,
#  'line': 2,
#  'room': 13,
#  'comfortable': 1,
#  'thirteen': 1,
#  'argued': 1,
#  'roughly': 1,
#  'itonce': 1,
#  'terribly': 1,
#  'books': 1,
#  'hat': 1,
#  'enormous': 1,
#  'not': 144,
#  'pardoned': 1,
#  'locks': 2,
#  'simplynever': 1,
#  'woodshe': 1,
#  'jurymen': 5,
#  'toss': 1,
#  'because': 15,
#  'themselves': 3,
#  'forepaws': 1,
#  'hurried': 11,
#  'earth': 4,
#  'muscular': 1,
#  'straight': 2,
#  'bent': 1,
#  'invitation': 2,
#  'quietly': 5,
#  'remarking': 3,
#  'reaching': 1,
#  'arrived': 1,
#  'gloves': 10,
#  'machines': 1,
#  'silent': 7,
#  'fulcrum': 1,
#  'sneezed': 1,
#  'bookshelves': 1,
#  'crashnow': 1,
#  'and': 845,
#  'folded': 3,
#  'lap': 2,
#  'uglification': 2,
#  'stand': 6,
#  'comfort': 1,
#  'housemaid': 1,
#  'nervous': 5,
#  'holding': 3,
#  'downhere': 1,
#  'shrinking': 4,
#  'thatll': 1,
#  'frogfootman': 1,
#  'bright': 7,
#  'executioner': 5,
#  'curtain': 1,
#  'bear': 1,
#  'flock': 1,
#  'lamps': 1,
#  'cant': 28,
#  'show': 3,
#  'answers': 1,
#  'above': 3,
#  'invited': 2,
#  'id': 11,
#  'already': 2,
#  'so': 150,
#  'meanwhile': 1,
#  'grazed': 1,
#  'sighed': 5,
#  'fair': 1,
#  'presented': 1,
#  'idiot': 1,
#  'theyre': 13,
#  'soup': 18,
#  'lory': 7,
#  'where': 13,
#  'accusation': 1,
#  'jar': 2,
#  'white': 30,
#  'dozing': 1,
#  'leading': 1,
#  'directed': 2,
#  'stopping': 1,
#  'begin': 13,
#  'argue': 1,
#  'dreadfully': 6,
#  'lessonbook': 1,
#  'one': 101,
#  'thoroughly': 2,
#  'off': 73,
#  'feared': 1,
#  'over': 40,
#  'immense': 1,
#  'flowerpot': 1,
#  'soldiers': 10,
#  'shrill': 5,
#  'manage': 7,
#  'pencil': 1,
#  'farther': 1,
#  'scratching': 1,
#  'alone': 4,
#  'down': 101,
#  'flowers': 2,
#  'list': 3,
#  'king': 61,
#  'obstacle': 1,
#  'set': 14,
#  'pigbaby': 1,
#  'letter': 3,
#  'killing': 1,
#  'positively': 1,
#  'mark': 3,
#  'paint': 1,
#  'stockings': 1,
#  'hanging': 3,
#  'ways': 1,
#  'conquest': 1,
#  'growls': 1,
#  'sluggard': 1,
#  'behead': 1,
#  'mice': 3,
#  'sorry': 1,
#  'animals': 5,
#  'examining': 1,
#  'tarts': 7,
#  'guilt': 1,
#  'duchess': 38,
#  'taken': 4,
#  'violent': 2,
#  'heap': 1,
#  'splendidly': 1,
#  'hare': 31,
#  'marked': 6,
#  'footman': 10,
#  'indignantly': 4,
#  'figure': 3,
#  'ravens': 1,
#  'song': 7,
#  'slippery': 1,
#  'oh': 38,
#  'wash': 2,
#  'barking': 1,
#  'hurriedly': 2,
#  'prize': 1,
#  'teatime': 2,
#  'giving': 2,
#  'myself': 7,
#  'distance': 7,
#  'carrying': 2,
#  'dark': 3,
#  'the': 1630,
#  'yelp': 1,
#  'whisper': 3,
#  'removed': 2,
#  'ask': 11,
#  'rapidly': 2,
#  'branches': 2,
#  'just': 51,
#  'awfully': 1,
#  'cauldron': 2,
#  'loose': 1,
#  'trembling': 6,
#  'high': 16,
#  'led': 4,
#  'few': 9,
#  'ones': 2,
#  'romeno': 1,
#  'fairytales': 1,
#  'sigh': 4,
#  'putting': 3,
#  'meeting': 1,
#  'fender': 1,
#  'enoughi': 1,
#  'wig': 2,
#  'languid': 1,
#  'trees': 7,
#  'limbs': 1,
#  'exactly': 8,
#  'hasnt': 2,
#  'sneeze': 2,
#  'live': 8,
#  'vii': 1,
#  'dull': 3,
#  'pig': 8,
#  'vi': 1,
#  'mousea': 1,
#  'uneasy': 1,
#  'many': 12,
#  'eaten': 1,
#  'cutting': 1,
#  'has': 7,
#  'manners': 1,
#  'daisychain': 1,
#  'kitchen': 4,
#  'win': 1,
#  'est': 1,
#  'understand': 6,
#  'back': 38,
#  'sorrowful': 2,
#  'tasted': 3,
#  'ordering': 2,
#  'childhood': 1,
#  'variations': 1,
#  'easily': 3,
#  'writingdesk': 1,
#  'least': 8,
#  'front': 2,
#  'invent': 1,
#  'hadnt': 8,
#  'queens': 8,
#  'curtsey': 1,
#  'violence': 1,
#  'impossible': 3,
#  'further': 3,
#  'encouraging': 2,
#  'looked': 45,
#  'precious': 1,
#  'returning': 1,
#  'way': 52,
#  'trickling': 1,
#  'contemptuously': 2,
#  'forgetting': 3,
#  'custody': 2,
#  'trials': 4,
#  'double': 1,
#  'indignant': 1,
#  'neednt': 3,
#  'flinging': 1,
#  'prison': 1,
#  'lonely': 2,
#  'quick': 2,
#  'make': 26,
#  'executions': 2,
#  'became': 2,
#  'bearmind': 1,
#  'heads': 11,
#  'flat': 2,
#  'finger': 5,
#  'on': 193,
#  'dears': 3,
#  'voice': 47,
#  'energetic': 1,
#  'squeaked': 1,
#  'my': 58,
#  'melancholy': 6,
#  'otherwise': 4,
#  'dodged': 1,
#  'saucer': 1,
#  'pack': 5,
#  'hoarse': 3,
#  'stretching': 2,
#  'breadknife': 1,
#  'broke': 2,
#  'execute': 1,
#  'sleepy': 5,
#  'printed': 1,
#  'sell': 2,
#  'knelt': 1,
#  'barleysugar': 1,
#  'pencils': 1,
#  'guard': 1,
#  'alice': 386,
#  'prizes': 5,
#  'cackled': 1,
#  'running': 8,
#  'catching': 2,
#  'explanation': 2,
#  'occasionally': 1,
#  'alternately': 1,
#  'certain': 3,
#  'letters': 1,
#  'isthe': 1,
#  'quarrel': 1,
#  'thrown': 1,
#  'falling': 2,
#  'turn': 10,
#  'curls': 1,
#  'loving': 1,
#  'entirely': 2,
#  'canvas': 1,
#  'realitythe': 1,
#  'day': 25,
#  'natural': 4,
#  'snout': 1,
#  'handed': 3,
#  'window': 8,
#  'oldest': 1,
#  'presents': 2,
#  'mouses': 1,
#  'officers': 4,
#  'appearing': 1,
#  'done': 15,
#  'recognised': 1,
#  'isoh': 2,
#  'being': 19,
#  'doing': 5,
#  'holiday': 1,
#  'persisted': 2,
#  'low': 14,
#  'redhot': 1,
#  'maynt': 1,
#  'theirs': 1,
#  'carried': 4,
#  'whose': 2,
#  'mouth': 10,
#  'pattern': 1,
#  'lastly': 1,
#  'puffed': 1,
#  'seated': 1,
#  'boy': 2,
#  'remarked': 10,
#  'poolshe': 1,
#  'itself': 14,
#  'several': 4,
#  'disagree': 1,
#  'pass': 1,
#  'egg': 1,
#  'bough': 1,
#  'seals': 1,
#  'cushion': 2,
#  'sudden': 5,
#  'come': 46,
#  'work': 8,
#  'cupboards': 2,
#  'beasts': 2,
#  'nevertheless': 1,
#  'drink': 7,
#  'mousetraps': 1,
#  'lesson': 1,
#  'both': 14,
#  'accidentally': 1,
#  'theyd': 4,
#  'tidy': 1,
#  'in': 366,
#  'raving': 2,
#  'instance': 3,
#  'offer': 2,
#  'justice': 1,
#  'coils': 1,
#  'music': 3,
#  'he': 120,
#  'various': 1,
#  'youve': 6,
#  'fancied': 2,
#  'opening': 3,
#  'learnt': 2,
#  'until': 5,
#  'v': 1,
#  'shape': 1,
#  'sharply': 4,
#  'bend': 2,
#  'hoarsely': 1,
#  'lasted': 2,
#  'sneezes': 2,
#  'mouseo': 1,
#  'knot': 2,
#  'whiskers': 3,
#  'fortunately': 1,
#  'birds': 9,
#  'summer': 2,
#  'worth': 4,
#  'disappointment': 1,
#  'impatiently': 5,
#  'fit': 3,
#  'william': 7,
#  'burst': 1,
#  'won': 2,
#  'lizard': 5,
#  'delighted': 2,
#  'swimming': 2,
#  'cheerfully': 1,
#  'fallen': 4,
#  'ennyworth': 1,
#  'odd': 1,
#  'condemn': 1,
#  'currants': 1,
#  'tillie': 1,
#  'red': 2,
#  'does': 9,
#  'plainly': 1,
#  'desperately': 1,
#  'mile': 2,
#  'lark': 1,
#  'skimming': 1,
#  'skurried': 1,
#  'better': 14,
#  'yelled': 1,
#  'longer': 3,
#  'told': 6,
#  'rubbed': 1,
#  'raven': 1,
#  'knows': 2,
#  'far': 13,
#  'confused': 4,
#  'toys': 1,
#  'a': 627,
#  'honour': 4,
#  'memorandum': 1,
#  'whatever': 3,
#  'voicethe': 1,
#  'farmyardwhile': 1,
#  'whiles': 1,
#  'punished': 1,
#  'particular': 4,
#  'thats': 33,
#  'tight': 1,
#  'antipathies': 1,
#  'soles': 1,
#  'pebbles': 2,
#  'collar': 1,
#  'leaves': 6,
#  'walked': 10,
#  'known': 1,
#  'owl': 3,
#  'before': 37,
#  'teaching': 1,
#  'circumstances': 1,
#  'teatray': 1,
#  'pleased': 7,
#  'absurd': 2,
#  'teacups': 2,
#  'these': 14,
#  'rosetree': 4,
#  'hurt': 3,
#  'sit': 8,
#  'account': 1,
#  'speaking': 5,
#  'pictured': 1,
#  'telescopes': 1,
#  'young': 5,
#  'couldnt': 9,
#  'engraved': 1,
#  'againbefore': 1,
#  'indeed': 16,
#  'esq': 1,
#  'derision': 1,
#  'meat': 1,
#  'near': 15,
#  'grumbled': 1,
#  'adoption': 1,
#  'milk': 1,
#  'eye': 7,
#  'railway': 2,
#  'candle': 3,
#  'anxious': 3,
#  'minded': 1,
#  'capering': 1,
#  'earnestly': 2,
#  'messages': 2,
#  'fight': 2,
#  'helped': 1,
#  'follow': 2,
#  'emphasis': 1,
#  'muchnessdid': 1,
#  'useful': 2,
#  'sort': 20,
#  'counting': 1,
#  'memory': 1,
#  'lying': 8,
#  'dinner': 2,
#  'belt': 1,
#  'shell': 3,
#  'began': 58,
#  'answer': 9,
#  'raised': 2,
#  'arguments': 1,
#  'theyyouve': 1,
#  'contemptuous': 1,
#  'ornamented': 2,
#  'hearthrug': 1,
#  'feathers': 1,
#  'drawlingthe': 1,
#  'shake': 1,
#  'rock': 1,
#  'signify': 1,
#  'effect': 3,
#  'fancying': 1,
#  'rabbitholeand': 1,
#  'questionshow': 1,
#  'muttered': 2,
#  'broken': 6,
#  'cat': 35,
#  'hearts': 8,
#  'corner': 3,
#  'coming': 9,
#  'carthorse': 1,
#  'law': 2,
#  'nodded': 1,
#  'ten': 6,
#  'hold': 9,
#  'reason': 9,
#  'slipped': 3,
#  'slightest': 1,
#  'livery': 3,
#  'cheshire': 7,
#  'absence': 1,
#  'listen': 7,
#  'blow': 2,
#  'succeeded': 3,
#  'ladderwhy': 1,
#  'hatters': 2,
#  'take': 21,
#  'shy': 1,
#  'xii': 1,
#  'advantage': 3,
#  'wait': 1,
#  'length': 1,
#  'escape': 4,
#  'whoever': 1,
#  'side': 17,
#  'bowing': 1,
#  'held': 4,
#  'passage': 4,
#  'home': 5,
#  'waters': 1,
#  'writingdesks': 1,
#  'aftertime': 1,
#  'lazy': 1,
#  'applause': 1,
#  'maps': 1,
#  'parchment': 2,
#  'saucepan': 1,
#  'supple': 1,
#  'perfectly': 4,
#  'adjourn': 1,
#  'voices': 2,
#  'below': 3,
#  'disobey': 1,
#  'all': 180,
#  'idiotic': 1,
#  'darkness': 1,
#  'catch': 3,
#  'turnup': 1,
#  'cool': 2,
#  'tittered': 1,
#  'protection': 1,
#  'cats': 15,
#  'house': 18,
#  'happens': 5,
#  'crouched': 1,
#  'fondofof': 1,
#  'becoming': 1,
#  'why': 39,
#  'rush': 2,
#  'next': 30,
#  'fork': 1,
#  'nicely': 2,
#  'denial': 1,
#  'friends': 2,
#  'liked': 6,
#  'witness': 10,
#  'smallest': 2,
#  'rapped': 1,
#  'ground': 4,
#  'mouseto': 1,
#  'fryingpan': 1,
#  'blows': 1,
#  'fairly': 1,
#  'pegs': 1,
#  'cause': 3,
#  'care': 4,
#  'roast': 1,
#  'four': 6,
#  'knave': 9,
#  'couple': 1,
#  'snappishly': 1,
#  'own': 10,
#  'evidence': 7,
#  'ladhere': 1,
#  'fellow': 4,
#  'beor': 1,
#  'our': 8,
#  'moving': 3,
#  'round': 41,
#  'laughter': 1,
#  'shoes': 7,
#  'fluttered': 1,
#  'dainties': 1,
#  'clubs': 1,
#  'struck': 2,
#  'whats': 5,
#  'pigeon': 12,
#  'stingy': 1,
#  'sentence': 6,
#  'itll': 8,
#  'lost': 3,
#  'face': 14,
#  'appearance': 1,
#  'ferrets': 2,
#  'ignorant': 1,
#  'give': 12,
#  'hearing': 4,
#  'rises': 1,
#  'mournful': 1,
#  'sensation': 2,
#  'smoke': 1,
#  'whistle': 1,
#  'pat': 2,
#  'sprawling': 1,
#  'longed': 2,
#  'undo': 1,
#  'must': 44,
#  'curly': 1,
#  'lowing': 1,
#  'shriek': 5,
#  'common': 1,
#  'upstairs': 1,
#  'conversations': 1,
#  'moreas': 1,
#  'affair': 1,
#  'farmer': 1,
#  'venture': 3,
#  'gallons': 1,
#  'frightened': 7,
#  'ive': 34,
#  'declare': 2,
#  'introduce': 2,
#  'say': 50,
#  'upset': 3,
#  'soand': 1,
#  'soldier': 1,
#  'shedding': 1,
#  'worm': 1,
#  'x': 1,
#  'heard': 30,
#  'snorting': 1,
#  'drunk': 2,
#  'eat': 18,
#  'stop': 6,
#  'readily': 1,
#  'jumping': 4,
#  'boldly': 1,
#  'hastily': 16,
#  'underneath': 1,
#  'zealand': 1,
#  'peeping': 1,
#  'small': 10,
#  'most': 8,
#  'woke': 1,
#  'mind': 10,
#  'sat': 17,
#  'pointing': 4,
#  'welcome': 1,
#  'which': 49,
#  'suppose': 14,
#  'drive': 2,
#  'seriously': 1,
#  'cur': 1,
#  'fading': 1,
#  'works': 1,
#  'certainly': 14,
#  'painting': 2,
#  'remained': 3,
#  'growl': 3,
#  'proved': 2,
#  'sentenced': 1,
#  'standing': 1,
#  'nor': 3,
#  'confusing': 3,
#  'thinand': 1,
#  'dinn': 2,
#  'conversation': 10,
#  'gently': 3,
#  'how': 64,
#  'hoping': 3,
#  'neither': 2,
#  'apples': 2,
#  'notebook': 2,
#  'key': 9,
#  'left': 14,
#  'paused': 1,
#  'listened': 1,
#  'unrolled': 2,
#  'cheated': 1,
#  'choking': 1,
#  'puzzle': 1,
#  'lessons': 10,
#  'throw': 3,
#  'treacle': 5,
#  'lefthand': 2,
#  'arranged': 1,
#  'shed': 2,
#  'now': 57,
#  'continued': 9,
#  'remarkable': 2,
#  'station': 1,
#  'entangled': 2,
#  'against': 9,
#  'first': 49,
#  'leap': 1,
#  'trampled': 1,
#  'morcar': 2,
#  'neighbour': 1,
#  'teeth': 1,
#  'paws': 4,
#  'judge': 4,
#  'wondering': 7,
#  'shant': 6,
#  'unfolded': 2,
#  'lines': 1,
#  'begged': 1,
#  'change': 14,
#  'respectable': 1,
#  'sobbing': 3,
#  'nurseand': 1,
#  'ringlets': 2,
#  'canterbury': 1,
#  'leaning': 2,
#  'halfpast': 2,
#  'presently': 2,
#  'sand': 1,
#  'tunnel': 1,
#  'doze': 1,
#  'proposal': 1,
#  'existence': 1,
#  'yesterday': 3,
#  'brave': 1,
#  'crowded': 5,
#  'processions': 1,
#  'lacie': 1,
#  'children': 10,
#  'notice': 5,
#  'places': 2,
#  'middle': 7,
#  'wings': 1,
#  'retire': 1,
#  'purple': 1,
#  'kiss': 1,
#  'humbly': 2,
#  'master': 3,
#  'half': 21,
#  'shouted': 9,
#  'largest': 1,
#  'declared': 1,
#  'form': 1,
#  'number': 5,
#  'cost': 1,
#  'linked': 1,
#  'curious': 19,
#  'simple': 5,
#  'dinahs': 1,
#  'by': 56,
#  'everything': 10,
#  'hide': 1,
#  'beating': 2,
#  'pocket': 6,
#  'bit': 16,
#  'beast': 1,
#  'overhead': 1,
#  'avoid': 1,
#  'sisters': 2,
#  'laughed': 2,
#  'daisies': 1,
#  'accounts': 1,
#  'cares': 2,
#  'curiouser': 2,
#  'little': 128,
#  'girl': 4,
#  'minutes': 11,
#  'stoop': 2,
#  'waterwell': 1,
#  'older': 2,
#  'hour': 2,
#  'fishand': 1,
#  'denied': 2,
#  'crowd': 4,
#  'doubledup': 1,
#  'repeat': 7,
#  'playing': 2,
#  'every': 12,
#  'disgust': 1,
#  'treat': 1,
#  'whether': 11,
#  'hottempered': 1,
#  'answered': 4,
#  'furiously': 1,
#  'nothing': 34,
#  'ifif': 1,
#  'lived': 3,
#  'blacking': 1,
#  'teacup': 3,
#  'dry': 8,
#  'usually': 2,
#  'spell': 1,
#  'pair': 5,
#  'onions': 1,
#  'wildly': 2,
#  'strings': 1,
#  'ugh': 2,
#  'curiosity': 5,
#  'want': 9,
#  'height': 5,
#  'followed': 8,
#  'likely': 5,
#  'hungry': 3,
#  'graceful': 1,
#  'verdict': 3,
#  'questions': 3,
#  'beds': 1,
#  'court': 18,
#  'denies': 1,
#  'elses': 1,
#  'execution': 2,
#  '\x1a': 1,
#  'brothers': 1,
#  'notion': 3,
#  'door': 29,
#  'velvet': 1,
#  'conclusion': 2,
#  'instead': 3,
#  'tumbled': 1,
#  'learn': 7,
#  'shes': 7,
#  'handsome': 1,
#  'going': 27,
#  'fine': 2,
#  'fashion': 2,
#  'politely': 6,
#  'judging': 1,
#  'is': 102,
#  'cheeks': 1,
#  'march': 33,
#  'tried': 19,
#  'measure': 1,
#  'pity': 3,
#  'dayschool': 1,
#  'scroll': 2,
#  'bursting': 1,
#  'puss': 1,
#  'act': 1,
#  'boyand': 1,
#  'growing': 11,
#  'em': 3,
#  'glanced': 1,
#  'grinning': 1,
#  'lobsters': 7,
#  'fills': 1,
#  'mock': 56,
#  'sir': 7,
#  'terror': 1,
#  'hated': 1,
#  'vinegar': 1,
#  'neverending': 1,
#  'alices': 12,
#  'creep': 1,
#  'deserved': 1,
#  'fifteenth': 1,
#  'pointed': 1,
#  'stole': 2,
#  'brushing': 1,
#  'table': 18,
#  'teathings': 1,
#  'hiss': 1,
#  'arminarm': 1,
#  'accustomed': 1,
#  'rightly': 1,
#  'rabbitspat': 1,
#  'head': 48,
#  'doubtfully': 2,
#  'since': 4,
#  'sobbed': 1,
#  'argument': 4,
#  'burning': 1,
#  'hopeless': 1,
#  'poison': 3,
#  'eyestell': 1,
#  'listeners': 1,
#  'rest': 10,
#  'thy': 1,
#  'agony': 1,
#  'simply': 2,
#  'past': 1,
#  'heavy': 2,
#  'bad': 2,
#  'smaller': 3,
#  'thimble': 4,
#  'rich': 1,
#  'crawled': 1,
#  'business': 7,
#  'content': 1,
#  'helpless': 1,
#  'desperate': 1,
#  'insolence': 1,
#  'saythats': 1,
#  'dropped': 5,
#  'immediately': 3,
#  'die': 1,
#  'forehead': 2,
#  'clearer': 1,
#  'lock': 1,
#  'muttering': 3,
#  'thousand': 2,
#  'hell': 1,
#  'snatch': 2,
#  'officer': 1,
#  'muchness': 2,
#  'warning': 1,
#  'finishing': 1,
#  'long': 32,
#  'jumped': 6,
#  'duck': 4,
#  'rattle': 1,
#  'rustled': 1,
#  ...}

# %%
def prefix_counter(file, prefix):
    d = word_frequency('alice30.txt')
    prefix = prefix.lower()
    result = []
    for k,v in d.items():
        if prefix == k[0:len(prefix)]:
            print(k,v)

prefix_counter('alice30.txt', 'you')
# Out:
#     Would you like to count capitalized words as a
#     separate word, or would you like me to make them all
#     lowercase? Please enter 'y' or 'n'!
# y
#
#     Ok, now would you like to print your list of words and
#     their count to the console?  Please enter 'y' or 'n'.
# n
# Got it! Capitals will be made lower-case. Here is your list.
#
# youve 6
# young 5
# youll 6
# youre 23
# yours 3
# your 62
# youth 6
# you 362
# youall 1
# yourself 10
# youd 10
# youare 1
